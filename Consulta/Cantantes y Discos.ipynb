# %%
import os
print("Deber Canatantes Disos")
def menu():
    
    os.system('clear') 
    print ("Selecciona una opción")
    print ("\t1 - Cantante")
    print ("\t2 - Disco")
    print ("\t3 - Salir")

def menu_cantante():
    
    os.system('clear') 
    print ("Selecciona una opción")
    print ("\t1 - Nuevo Cantante")
    print ("\t2 - Consultar Cantante")
    print ("\t3 - Modificar Cantante")
    print ("\t4 - Eliminar Cantante")
    print ("\t5 - Salir")

def menu_disco():
    
    os.system('clear') 
    print ("Selecciona una opción") 
    print ("\t1 - Nuevo Disco")
    print ("\t2 - Consultar Disco")
    print ("\t3 - Modificar Disco")
    print ("\t4 - Eliminar Disco")
    print ("\t5 - Salir")    

while True:
  
    menu()
    opcionMenu = input("Escoje una opcion del menu: ")
    
    if opcionMenu=="1":
        menu_cantante()
        opcionMenuCantante = input("Escoje una opcion del menu: ")
        
        if opcionMenuCantante=="1":
            print ("")     
            nombre_cantante = input("Ingrese nombre del cantante: ")
            edad_cantante = input("Ingrese edad del cantante: ")
            sexo_cantante = input("Ingrese sexo del cantante: ")
            genero_cantante = input("Ingrese genero musical: ")
            pais_cantante = input("Ingrese pais del cantante: ")
       
        
            try:
                path = "./cantante.txt"
                archivo_abierto_escritura = open(path,mode="a")
                archivo_abierto_escritura.write(f"{nombre_cantante}, ")
                archivo_abierto_escritura.write(f"{edad_cantante}, ")
                archivo_abierto_escritura.write(f"{sexo_cantante},")
                archivo_abierto_escritura.write(f"{genero_cantante},")
                archivo_abierto_escritura.write(f"{pais_cantante},\n")
                archivo_abierto_escritura.close()
            except Exception as error:
                print('error cantante')
            
        elif opcionMenuCantante=="2":
            print ("")
            try:
                path = "./cantante.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                for linea in contenido:
                    print(linea)
                archivo_abierto.close()
            except Exception as error:
                print('error cantante')   
        elif opcionMenuCantante=="3":
            print ("")
            try:
                path = "./cantante.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                archivo_abierto.close()
                archivo_abierto = open(path,mode="w")
            
                for linea in contenido:
                    print(linea)
                linea_eliminar = input("Ingrese los datos del cantante a modificar: ")
                linea_agregar = input("Ingrese los datos del cantante modificado: ")
                for linea in contenido:
                    if linea != f"{linea_eliminar}\n":
                        archivo_abierto.write(f"{linea}")
                    else:
                        archivo_abierto.write(f"{linea_agregar}\n")
                archivo_abierto.close()
            except Exception as error:
                print('error')
        elif opcionMenuCantante=="4":
            print ("")
            try:
                path = "./cantante.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                archivo_abierto.close()
                archivo_abierto = open(path,mode="w")
            
                for linea in contenido:
                    print(linea)
                linea_eliminar = input("Ingrese los datos del cantante a eliminar: ")
                for linea in contenido:
                    if linea != f"{linea_eliminar}\n":
                        archivo_abierto.write(f"{linea}")
                archivo_abierto.close()
            except Exception as error:
                print('error cantante')
        elif opcionMenuCantante=="5":
            break
        
        else:
            print ("")
            input("No has seleccionado una opcion...\n Selecciona una opcion del menu")   
    
    elif opcionMenu=="2":
        menu_disco()
        opcionMenuDisco = input("Escoje una opcion del menu: ")
        if opcionMenuDisco=="1":
        
            print ("")
            nombre_disco = input("Ingrese el nombre del disco: ")
            tipo_disco = input("Ingrese tipo de disco: ")
            precio_disco = input("Ingrese el precio del disco: ")
            anio_disco = input("Ingrese el anio de grabacion: ")
            tracklist_disco = input("Ingrese la cancion mas escuchada")
            
       
        
            try:
                path = "./disco.txt"
                archivo_abierto_escritura = open(path,mode="a")
                archivo_abierto_escritura.write(f"{nombre_disco}, ")
                archivo_abierto_escritura.write(f"{tipo_disco}, ")
                archivo_abierto_escritura.write(f"{precio_disco},")
                archivo_abierto_escritura.write(f"{anio_disco},")
                archivo_abierto_escritura.write(f"{tracklist_disco}\n")
                archivo_abierto_escritura.close()
            except Exception as error:
                print('error disco')
            
        elif opcionMenuDisco=="2":
            print ("")
            try:
                path = "./disco.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                for linea in contenido:
                    print(linea)
                archivo_abierto.close()
            except Exception as error:
                print('error disco')
    
        elif opcionMenuDisco=="3":
            print ("")
            try:
                path = "./disco.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                archivo_abierto.close()
                archivo_abierto = open(path,mode="w")
            
                for linea in contenido:
                    print(linea)
                linea_eliminar = input("Ingrese el disco a modificar: ")
                linea_agregar = input("Ingrese el disco modificado: ")
                for linea in contenido:
                    if linea != f"{linea_eliminar}\n":
                        archivo_abierto.write(f"{linea}")
                    else:
                        archivo_abierto.write(f"{linea_agregar}\n")
                archivo_abierto.close()
            except Exception as error:
                print('error disco')

        elif opcionMenuMedicina=="4":
            print ("")
            try:
                path = "./disco.txt"
                archivo_abierto = open(path)
                contenido = archivo_abierto.readlines()
                archivo_abierto.close()
                archivo_abierto = open(path,mode="w")
            
                for linea in contenido:
                    print(linea)
                linea_eliminar = input("Ingrese los datos del disco a eliminar: ")
                for linea in contenido:
                    if linea != f"{linea_eliminar}\n":
                        archivo_abierto.write(f"{linea}")
                archivo_abierto.close()
            except Exception as error:
                print('error disco')
        
        
        elif opcionMenuDisco=="5":
            break
        
        
        else:
            print ("")
            input("No has seleccionado una opcion...\n Selecciona una opcion del menu") 
     
    
    elif opcionMenu=="3":
        break
    else:
        print ("")
        input("No has seleccionado una opcion...\n Selecciona una opcion del menu")
# Out:
# Deber Canatantes Disos
# Selecciona una opción
# 	1 - Cantante
# 	2 - Disco
# 	3 - Salir
# Escoje una opcion del menu: 1
# Selecciona una opción
# 	1 - Nuevo Cantante
# 	2 - Consultar Cantante
# 	3 - Modificar Cantante
# 	4 - Eliminar Cantante
# 	5 - Salir
# Escoje una opcion del menu: 1
#
# Ingrese nombre del cantante: KSADJ
# Ingrese edad del cantante: ASKLFJ
# Ingrese sexo del cantante: ASKFJD
# Ingrese genero musical: ASLKF
# Ingrese pais del cantante: ASAKDJF
# Selecciona una opción
# 	1 - Cantante
# 	2 - Disco
# 	3 - Salir
# Escoje una opcion del menu: 1
# Selecciona una opción
# 	1 - Nuevo Cantante
# 	2 - Consultar Cantante
# 	3 - Modificar Cantante
# 	4 - Eliminar Cantante
# 	5 - Salir
# Escoje una opcion del menu: 2
#
#
#
# Angra, 34, masculini
#
# Tommy, 45, masculino
#
# rock
#
# brasil
#
# Angra, 34, M
#
# ROCK
#
# ESPAÑA
#
# ANGRA, 34, MASCUNI,ROCK,BRASIL},
#
# KSADJ, ASKLFJ, ASKFJD,ASLKF,ASAKDJF,
#
# Selecciona una opción
# 	1 - Cantante
# 	2 - Disco
# 	3 - Salir
# ...
